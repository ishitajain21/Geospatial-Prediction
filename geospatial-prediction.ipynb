# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import geopandas as gpd
import json
import matplotlib.pyplot as plt
import geojson
import folium
import descartes
from shapely.geometry import Point, Polygon
# %matplotlib inline

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/us-county/USA_Counties.shp
# /kaggle/input/us-county/USA_Counties.cpg
# /kaggle/input/us-county/USA_Counties.prj
# /kaggle/input/us-county/USA_Counties.dbf
# /kaggle/input/us-county/USA_Counties.shx
# /kaggle/input/american-tribal/NativeAmerican.geojson
# /kaggle/input/temp22/temp22.csv
# /kaggle/input/precip22/Precip22.csv

# %%
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# import seaborn as sns
# import geopandas as gpd
# import json
# import matplotlib.pyplot as plt
# import geojson
# import folium
# from shapely.geometry import Point, Polygon

# geographic = gpd.read_file("data/uscounties/USA_Counties.shp")
# geographic = geographic[['NAME','STATE_NAME','geometry']]
#     #geographic.drop(geographic.columns.difference(['NAME','STATE_NAME','geometry']),1,inplace=True)
# geographic['STATE_NAME'] =geographic['STATE_NAME'].str.upper()
# geographic = geographic[geographic.STATE_NAME != "PUERTO RICO"]
# geographic = geographic[geographic.STATE_NAME != "ALASKA"]
# geographic.rename(columns={'NAME':'County'},inplace=True)
# geographic['County'] = geographic['County'].str.lower()
# geographic["State"] = geographic["STATE_NAME"]

# tribal = gpd.read_file("data/NativeAmerican.geojson")
# precip = pd.read_csv("data/Precip22.csv")
# temp = pd.read_csv("data/temp22.csv")

# precip[['State','ID']] = precip['Location ID'].str.split('-',expand=True)

# temp[['State','ID']] = temp['Location ID'].str.split('-',expand=True)
# precip = precip[precip.State!="AK"]


# temp.State.unique()
# temp = temp[temp.State!="AK"]

# precip['Location'] = precip['Location'].str.split(' ',expand=True)[0]
# precip.drop(['Location ID','Rank','Anomaly (1901-2000 base period)','1901-2000 Mean'], axis=1,inplace=True)
# precip.rename(columns={'Value':'Precipitation (inches)'},inplace=True)

# temp['Location'] = temp['Location'].str.split(' ',expand=True)[0]
# temp.drop(['Location ID','Rank','Anomaly (1901-2000 base period)','1901-2000 Mean'], axis=1,inplace=True)
# temp.rename(columns={'Value':'Temp (F)'},inplace=True)

# us_state_to_abbrev = {
#     "Alabama": "AL",
#     "Alaska": "AK",
#     "Arizona": "AZ",
#     "Arkansas": "AR",
#     "California": "CA",
#     "Colorado": "CO",
#     "Connecticut": "CT",
#     "Delaware": "DE",
#     "Florida": "FL",
#     "Georgia": "GA",
#     "Hawaii": "HI",
#     "Idaho": "ID",
#     "Illinois": "IL",
#     "Indiana": "IN",
#     "Iowa": "IA",
#     "Kansas": "KS",
#     "Kentucky": "KY",
#     "Louisiana": "LA",
#     "Maine": "ME",
#     "Maryland": "MD",
#     "Massachusetts": "MA",
#     "Michigan": "MI",
#     "Minnesota": "MN",
#     "Mississippi": "MS",
#     "Missouri": "MO",
#     "Montana": "MT",
#     "Nebraska": "NE",
#     "Nevada": "NV",
#     "New Hampshire": "NH",
#     "New Jersey": "NJ",
#     "New Mexico": "NM",
#     "New York": "NY",
#     "North Carolina": "NC",
#     "North Dakota": "ND",
#     "Ohio": "OH",
#     "Oklahoma": "OK",
#     "Oregon": "OR",
#     "Pennsylvania": "PA",
#     "Rhode Island": "RI",
#     "South Carolina": "SC",
#     "South Dakota": "SD",
#     "Tennessee": "TN",
#     "Texas": "TX",
#     "Utah": "UT",
#     "Vermont": "VT",
#     "Virginia": "VA",
#     "Washington": "WA",
#     "West Virginia": "WV",
#     "Wisconsin": "WI",
#     "Wyoming": "WY",
#     "District of Columbia": "DC",
#     "American Samoa": "AS",
#     "Guam": "GU",
#     "Northern Mariana Islands": "MP",
#     "Puerto Rico": "PR",
#     "United States Minor Outlying Islands": "UM",
#     "U.S. Virgin Islands": "VI",
# }

# us_state_to_abbrev =  {k.lower(): v for k, v in us_state_to_abbrev.items()}

# geographic["STATE_NAME"] =  geographic["STATE_NAME"].str.lower()
# geographic["STATE_NAME"] = geographic["STATE_NAME"].map(us_state_to_abbrev)

# precip["STATE_NAME"] = precip["State"]
# precip.rename(columns={'Location':'County'},inplace=True)
# precip['County'] = precip['County'].str.lower()
# # precip_data= precip.merge(geographic,how="inner", right_on=["County",'STATE_NAME'], left_on=['County','STATE_NAME'])
# precip['Precipitation (inches)'] = precip['Precipitation (inches)'] .astype(int)
# #precip_gpd = gpd.GeoDataFrame(precip_data)

# temp["STATE_NAME"] = temp["State"]
# temp.rename(columns={'Location':'County'},inplace=True)
# temp['County'] = temp['County'].str.lower()
# #temp_data= temp.merge(geographic,how="inner", right_on=["County",'STATE_NAME'], left_on=['County','STATE_NAME'])
# temp['Temp (F)'] = temp['Temp (F)'] .astype(int)
# #temp_gpd = gpd.GeoDataFrame(temp_data)

# %%
# tribal_df = tribal_df[['TRIBAL_NM','geometry']]
# state_df = state_df["geometry"]

# %%
# import folium
# from folium import plugins
# #import rioxarray as rxr
# # import earthpy as et
# # import earthpy.spatial as es

# %%
# m = folium.Map(location=[47.7511, -120.7401])
# 
# #folium.GeoJson(state_df).add_to(m)

# # Display the map
# m

# %%
geographic = gpd.read_file("/kaggle/input/us-county/USA_Counties.shp")
geographic = geographic[['NAME','STATE_NAME','geometry']]
#geographic.drop(geographic.columns.difference(['NAME','STATE_NAME','geometry']),1,inplace=True)
geographic['STATE_NAME'] =geographic['STATE_NAME'].str.upper()
geographic = geographic[geographic.STATE_NAME != "PUERTO RICO"]
geographic = geographic[geographic.STATE_NAME != "ALASKA"]
geographic.rename(columns={'NAME':'County'},inplace=True)
geographic['County'] = geographic['County'].str.lower()
geographic["State"] = geographic["STATE_NAME"]

# %%
geographic
# Out:
#            County STATE_NAME  \
# 0          graham    ARIZONA
# 1        greenlee    ARIZONA
# 2          bureau   ILLINOIS
# 3          la paz    ARIZONA
# 4         calhoun   ILLINOIS
# ...           ...        ...
# 3205      shawano  WISCONSIN
# 3207    sheboygan  WISCONSIN
# 3208       taylor  WISCONSIN
# 3210  trempealeau  WISCONSIN
# 3213       vernon  WISCONSIN
#
#                                                geometry      State
# 0     MULTIPOLYGON (((-12217131.319 3959728.262, -12...    ARIZONA
# 1     POLYGON ((-12139871.371 3999069.283, -12139050...    ARIZONA
# 2     POLYGON ((-9925971.867 5099065.657, -9925971.4...   ILLINOIS
# 3     MULTIPOLYGON (((-12720330.271 3924275.838, -12...    ARIZONA
# 4     POLYGON ((-10116327.032 4779103.377, -10116308...   ILLINOIS
# ...                                                 ...        ...
# 3205  POLYGON ((-9913342.298 5626214.097, -9911045.7...  WISCONSIN
# 3207  POLYGON ((-9768124.023 5448792.161, -9767845.0...  WISCONSIN
# 3208  POLYGON ((-10027736.770 5681910.527, -10026432...  WISCONSIN
# 3210  MULTIPOLYGON (((-10172919.080 5462992.003, -10...  WISCONSIN
# 3213  POLYGON ((-10053508.568 5423555.424, -10053511...  WISCONSIN
#
# [3114 rows x 4 columns]

# %%
tribal = gpd.read_file("/kaggle/input/american-tribal/NativeAmerican.geojson")

# %%
tribal
# Out:
#      FID  OBJECTID          AREA      PERIMETER  AIR_020107  AIR__20108  \
# 0      1         0  9.797569e+03     395.939726        9755        1378
# 1      2         0  4.761486e+07  232898.716483        9594        1544
# 2      3         0  1.020220e+09  251823.855945        9035        2104
# 3      4         0  4.632048e+08  147458.736295        9858        1275
# 4      5         0  1.517201e+06    4406.634868         201       11002
# ..   ...       ...           ...            ...         ...         ...
# 693  694         0  1.533998e+06    4510.339946         114       11089
# 694  695         0  1.532594e+06    4425.053791         136       11067
# 695  696         0  1.447354e+07   19545.724550       10738         373
# 696  697         0  8.533133e+07   63318.010761       10896         158
# 697  698         0  1.535317e+06    4457.276092          73       11130
#
#     R_CODE                                       IND_NAME  AIANA  \
# 0     T820  Absentee-Shawnee Tribe of Indians of Oklahoma   FRTE
# 1     R820              Absentee-Shawnee Tribe Trust Land  TRUST
# 2     R703                                   Acoma Pueblo    AIR
# 3     R703               Acoma Pueblo - Red Lake Purchase    AIR
# 4     Z002                                        Afognak    ANV
# ..     ...                                            ...    ...
# 693   Z294                             Manley Hot Springs    ANV
# 694   Z295                                      Manokotak    ANV
# 695   R579                          Manzanita Reservation    AIR
# 696   R612                 Maricopa (Ak-Chin) Reservation    AIR
# 697   Z297                                       Marshall    ANV
#
#                                      AIANA_DESC  ... FIELD_VERI  \
# 0            Federally Recognized Tribal Entity  ...
# 1    Trust land for which no reservation exists  ...
# 2                   American Indian Reservation  ...
# 3                   American Indian Reservation  ...
# 4                         Alaska Native Village  ...
# ..                                          ...  ...        ...
# 693                       Alaska Native Village  ...
# 694                       Alaska Native Village  ...
# 695                 American Indian Reservation  ...
# 696                 American Indian Reservation  ...
# 697                       Alaska Native Village  ...
#
#         Shape_Leng Shape_Le_1 Shape_Le_2 IRMP_Plan Short_Name     Shape_Le_3  \
# 0       395.939800        0.0        0.0                          395.939800
# 1    232898.716603        0.0        0.0                       232898.716605
# 2    251823.855918        0.0        0.0                       251823.855918
# 3    147458.736134        0.0        0.0                       147458.736134
# 4      4406.634913        0.0        0.0                         4406.634913
# ..             ...        ...        ...       ...        ...            ...
# 693    4510.339968        0.0        0.0                         4510.339968
# 694    4425.053808        0.0        0.0                         4425.053808
# 695   19545.724808        0.0        0.0                        19545.724808
# 696   63318.010448        0.0        0.0                        63318.010448
# 697    4457.276045        0.0        0.0                         4457.276045
#
#     SHAPE_Length    SHAPE_Area  \
# 0       0.003968  9.797573e+03
# 1       2.325178  4.761486e+07
# 2       2.517365  1.020220e+09
# 3       1.463367  4.632048e+08
# 4       0.058343  1.517201e+06
# ..           ...           ...
# 693     0.069126  1.533998e+06
# 694     0.059591  1.532594e+06
# 695     0.192554  1.447354e+07
# 696     0.630504  8.533133e+07
# 697     0.063685  1.535317e+06
#
#                                               geometry
# 0    MULTIPOLYGON (((-96.91030 35.32606, -96.91141 ...
# 1    MULTIPOLYGON (((-97.12493 35.19591, -97.12490 ...
# 2    MULTIPOLYGON (((-107.83181 34.86956, -107.8266...
# 3    MULTIPOLYGON (((-107.66447 34.46319, -107.6639...
# 4    MULTIPOLYGON (((-152.76839 58.00935, -152.7693...
# ..                                                 ...
# 693  MULTIPOLYGON (((-150.62488 64.99657, -150.6260...
# 694  MULTIPOLYGON (((-159.04654 58.97461, -159.0475...
# 695  MULTIPOLYGON (((-116.36104 32.73434, -116.3610...
# 696  MULTIPOLYGON (((-112.08291 33.07619, -112.0828...
# 697  MULTIPOLYGON (((-162.07275 61.87328, -162.0737...
#
# [698 rows x 56 columns]

# %%
precip = pd.read_csv("/kaggle/input/precip22/Precip22.csv")
temp = pd.read_csv("/kaggle/input/temp22/temp22.csv")

# %%
precip
# Out:
#      Location ID                         Location  Value  Rank  \
# 0         AL-001                   Autauga County   2.42    28
# 1         AL-003                   Baldwin County   4.47    52
# 2         AL-005                   Barbour County   2.58    26
# 3         AL-007                      Bibb County   4.00    71
# 4         AL-009                    Blount County   4.51    83
# ...          ...                              ...    ...   ...
# 3132      AK-230             Skagway Municipality   2.15    50
# 3133      AK-240  Southeast Fairbanks Census Area   1.96    18
# 3134      AK-275        Wrangell City and Borough   3.60    18
# 3135      AK-282         Yakutat City and Borough   3.68    10
# 3136      AK-290        Yukon-Koyukuk Census Area   0.54     2
#
#       Anomaly (1901-2000 base period)  1901-2000 Mean
# 0                             -1.5800            4.00
# 1                             -0.9173            5.39
# 2                             -1.5587            4.14
# 3                             -0.1475            4.15
# 4                              0.4753            4.03
# ...                               ...             ...
# 3132                          -0.1799            2.33
# 3133                          -0.6226            2.58
# 3134                          -2.3038            5.90
# 3135                          -4.5903            8.27
# 3136                          -1.0229            1.56
#
# [3137 rows x 6 columns]

# %%
precip[['State','ID']] = precip['Location ID'].str.split('-',expand=True)

temp[['State','ID']] = temp['Location ID'].str.split('-',expand=True)
precip = precip[precip.State!="AK"]


temp.State.unique()
temp = temp[temp.State!="AK"]

precip['Location'] = precip['Location'].str.split(' ',expand=True)[0]
precip.drop(['Location ID','Rank','Anomaly (1901-2000 base period)','1901-2000 Mean'], axis=1,inplace=True)
precip.rename(columns={'Value':'Precipitation (inches)'},inplace=True)

temp['Location'] = temp['Location'].str.split(' ',expand=True)[0]
temp.drop(['Location ID','Rank','Anomaly (1901-2000 base period)','1901-2000 Mean'], axis=1,inplace=True)
temp.rename(columns={'Value':'Temp (F)'},inplace=True)
# Out:
# /tmp/ipykernel_32/1682302320.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip['Location'] = precip['Location'].str.split(' ',expand=True)[0]
# /tmp/ipykernel_32/1682302320.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip.drop(['Location ID','Rank','Anomaly (1901-2000 base period)','1901-2000 Mean'], axis=1,inplace=True)
# /tmp/ipykernel_32/1682302320.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip.rename(columns={'Value':'Precipitation (inches)'},inplace=True)

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

us_state_to_abbrev =  {k.lower(): v for k, v in us_state_to_abbrev.items()}

# %%
geographic["STATE_NAME"] =  geographic["STATE_NAME"].str.lower()
geographic["STATE_NAME"] = geographic["STATE_NAME"].map(us_state_to_abbrev)

# %%
precip["STATE_NAME"] = precip["State"]
precip.rename(columns={'Location':'County'},inplace=True)
precip['County'] = precip['County'].str.lower()
# precip_data= precip.merge(geographic,how="inner", right_on=["County",'STATE_NAME'], left_on=['County','STATE_NAME'])
precip['Precipitation (inches)'] = precip['Precipitation (inches)'] .astype(int)
#precip_gpd = gpd.GeoDataFrame(precip_data)
# Out:
# /tmp/ipykernel_32/622052844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip["STATE_NAME"] = precip["State"]
# /tmp/ipykernel_32/622052844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip.rename(columns={'Location':'County'},inplace=True)
# /tmp/ipykernel_32/622052844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip['County'] = precip['County'].str.lower()
# /tmp/ipykernel_32/622052844.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip['Precipitation (inches)'] = precip['Precipitation (inches)'] .astype(int)

# %%
temp["STATE_NAME"] = temp["State"]
temp.rename(columns={'Location':'County'},inplace=True)
temp['County'] = temp['County'].str.lower()
#temp_data= temp.merge(geographic,how="inner", right_on=["County",'STATE_NAME'], left_on=['County','STATE_NAME'])
temp['Temp (F)'] = temp['Temp (F)'] .astype(int)
#temp_gpd = gpd.GeoDataFrame(temp_data)

# %%
precip.set_index
# Out:
# <bound method DataFrame.set_index of           County  Precipitation (inches) State   ID STATE_NAME
# 0        autauga                       2    AL  001         AL
# 1        baldwin                       4    AL  003         AL
# 2        barbour                       2    AL  005         AL
# 3           bibb                       4    AL  007         AL
# 4         blount                       4    AL  009         AL
# ...          ...                     ...   ...  ...        ...
# 3102  sweetwater                       1    WY  037         WY
# 3103       teton                       2    WY  039         WY
# 3104       uinta                       1    WY  041         WY
# 3105    washakie                       0    WY  043         WY
# 3106      weston                       1    WY  045         WY
#
# [3107 rows x 5 columns]>

# %%
# when you get the location of the user in latitude and longitude, replace with the variables. 
lat = 44
long = -103
m = folium.Map(location=[lat, long])
folium.GeoJson(tribal).add_to(m)

folium.Choropleth(
    geo_data=geographic,
    data=precip,
    columns=["County", "Precipitation (inches)"],
    key_on="feature.properties.County",
    fill_opacity = 0.7,
    line_opacity = 0.2,
    legend_name = "Precipitation"
).add_to(m)

folium.Marker(
    location=[48.1134, -123.7986], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Severe Winter Storm', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[48.5897,-119.6522], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Severe Winter Storm', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[34.0522, -118.2437], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Soboba Band of Luiseno Indians: Severe Winter Storm and Flooding', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[35.5175, -86.5804], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Severe Thunderstorms', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[34.9727, -105.0324], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Las Tusas Fire', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

#folium.GeoJson(state_df).add_to(m)

# Display the map
m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 7
#       4 m = folium.Map(location=[lat, long])
#       5 folium.GeoJson(tribal).add_to(m)
# ----> 7 folium.Choropleth(
#       8     geo_data=geographic,
#       9     data=precip,
#      10     columns=["County", "Precipitation (inches)"],
#      11     key_on="feature.properties.County",
#      12     fill_opacity = 0.7,
#      13     line_opacity = 0.2,
#      14     legend_name = "Precipitation"
#      15 ).add_to(m)
#      17 folium.Marker(
#      18     location=[48.1134, -123.7986], # coordinates for the marker (Earth Lab at CU Boulder)
#      19     popup='Severe Winter Storm', # pop-up label for the marker
#      20     icon=folium.Icon()
#      21 ).add_to(m)
#      23 folium.Marker(
#      24     location=[48.5897,-119.6522], # coordinates for the marker (Earth Lab at CU Boulder)
#      25     popup='Severe Winter Storm', # pop-up label for the marker
#      26     icon=folium.Icon()
#      27 ).add_to(m)
#
# File /opt/conda/lib/python3.10/site-packages/folium/features.py:1589, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1582     self.geojson = TopoJson(
#    1583         geo_data,
#    1584         topojson,
#    1585         style_function=style_function,
#    1586         smooth_factor=smooth_factor,
#    1587     )
#    1588 else:
# -> 1589     self.geojson = GeoJson(
#    1590         geo_data,
#    1591         style_function=style_function,
#    1592         smooth_factor=smooth_factor,
#    1593         highlight_function=highlight_function if highlight else None,
#    1594     )
#    1596 self.add_child(self.geojson)
#    1597 if self.color_scale:
#
# File /opt/conda/lib/python3.10/site-packages/folium/features.py:643, in GeoJson.__init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     638         raise TypeError(
#     639             "Only Marker, Circle, and CircleMarker are supported as GeoJson marker types."
#     640         )
#     641 self.marker = marker
# --> 643 self.data = self.process_data(data)
#     645 if self.style or self.highlight:
#     646     self.convert_to_feature_collection()
#
# File /opt/conda/lib/python3.10/site-packages/folium/features.py:685, in GeoJson.process_data(self, data)
#     683     self.embed = True
#     684     if hasattr(data, "to_crs"):
# --> 685         data = data.to_crs("EPSG:4326")
#     686     return json.loads(json.dumps(data.__geo_interface__))
#     687 else:
#
# File /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:1424, in GeoDataFrame.to_crs(self, crs, epsg, inplace)
#    1422 else:
#    1423     df = self.copy()
# -> 1424 geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1425 df.geometry = geom
#    1426 if not inplace:
#
# File /opt/conda/lib/python3.10/site-packages/geopandas/geoseries.py:1134, in GeoSeries.to_crs(self, crs, epsg)
#    1057 def to_crs(self, crs=None, epsg=None):
#    1058     """Returns a ``GeoSeries`` with all geometries transformed to a new
#    1059     coordinate reference system.
#    1060
#    (...)
#    1131
#    1132     """
#    1133     return GeoSeries(
# -> 1134         self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1135     )
#
# File /opt/conda/lib/python3.10/site-packages/geopandas/array.py:809, in GeometryArray.to_crs(self, crs, epsg)
#     805     return self
#     807 transformer = TransformerFromCRS(self.crs, crs, always_xy=True)
# --> 809 new_data = vectorized.transform(self._data, transformer.transform)
#     810 return GeometryArray(new_data, crs=crs)
#
# File /opt/conda/lib/python3.10/site-packages/geopandas/_vectorized.py:1174, in transform(data, func)
#    1172         result[i] = geom
#    1173     else:
# -> 1174         result[i] = transform(func, geom)
#    1176 return result
#
# File /opt/conda/lib/python3.10/site-packages/shapely/ops.py:306, in transform(func, geom)
#     303     elif geom.type == 'Polygon':
#     304         shell = type(geom.exterior)(
#     305             zip(*func(*zip(*geom.exterior.coords))))
# --> 306         holes = list(type(ring)(zip(*func(*zip(*ring.coords))))
#     307                      for ring in geom.interiors)
#     308         return type(geom)(shell, holes)
#     310 # A func that assumes x, y, z are single values will likely raise a
#     311 # TypeError, in which case we'll try again.
#
# File /opt/conda/lib/python3.10/site-packages/shapely/ops.py:306, in <genexpr>(.0)
#     303     elif geom.type == 'Polygon':
#     304         shell = type(geom.exterior)(
#     305             zip(*func(*zip(*geom.exterior.coords))))
# --> 306         holes = list(type(ring)(zip(*func(*zip(*ring.coords))))
#     307                      for ring in geom.interiors)
#     308         return type(geom)(shell, holes)
#     310 # A func that assumes x, y, z are single values will likely raise a
#     311 # TypeError, in which case we'll try again.
#
# KeyboardInterrupt:

# %%
# from pprint import pprint
# pprint(geographic.head().to_json())

# %%
temp['Temp (F)']

# %%
# when you get the location of the user in latitude and longitude, replace with the variables. 
lat = 44
long = -103
m = folium.Map(location=[lat, long])
folium.GeoJson(tribal).add_to(m)

folium.Choropleth(
    geo_data=geographic,
    data=temp,
    columns=["County", "Temp (F)"],
    fill_color = 'RdYlBu',
    key_on="feature.properties.County",
    fill_opacity = 0.7,
    line_opacity = 0.2,
    legend_name = "Temperature"
).add_to(m)

folium.Marker(
    location=[48.1134, -123.7986], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Severe Winter Storm', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[48.5897,-119.6522], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Severe Winter Storm', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[34.0522, -118.2437], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Soboba Band of Luiseno Indians: Severe Winter Storm and Flooding', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[35.5175, -86.5804], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Severe Thunderstorms', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

folium.Marker(
    location=[34.9727, -105.0324], # coordinates for the marker (Earth Lab at CU Boulder)
    popup='Las Tusas Fire', # pop-up label for the marker
    icon=folium.Icon()
).add_to(m)

#folium.GeoJson(state_df).add_to(m)

# Display the map
m
